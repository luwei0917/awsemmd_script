# %%
import os
import sys
import random
import time
from random import seed, randint
import argparse
import platform
from datetime import datetime
import imp
import numpy as np
import fileinput
from itertools import product
import pandas as pd
from scipy.interpolate import griddata
from scipy.interpolate import interp2d
import seaborn as sns
from os import listdir
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.interpolate import griddata
import matplotlib as mpl
sys.path.insert(0,'..')
from notebookFunctions import *
# from .. import notebookFunctions

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10,6.180)    #golden ratio
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2

# %%
file = "/Users/weilu/Research/server/sep_2018/abeta/thrid/simulation/2/0/energy.dat"

# %%
data = pd.read_csv(file)
data.columns = data.columns.str.strip()
data.plot("Steps", "Membrane")

# %%
data.columns
# Out:
# Index(['Steps', 'Chain', 'Chi', 'Rama', 'Water', 'Helix', 'AMH-Go', 'Frag_Mem',
#        'Membrane', 'VTotal', 'Ebond', 'Epair'],
#       dtype='object')

# %%
data.plot("Steps", "Membrane")
